# %% [markdown]
# <a href="https://colab.research.google.com/github/YoungtheFirst/Who_is_YoungtheFirst/blob/main/Copy_of_Python_crash_course.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 18 October 2023  -  Python crash course
#
# Paolo Rabino
#
# paolo.rabino@polito.it
#
# Link to notebook: [https://github.com/paolotron/PythonCrashCourse](https://github.com/paolotron/PythonCrashCourse)
#
# <img src="https://github.com/paolotron/PythonCrashCourse/blob/main/qr.png?raw=1" alt="drawing" width="200"/>

# %%
print("Hello world from mohsen")
# Out:
# Hello world from mohsen

# %% [markdown]
# ## Content
#
#  - Introduction to Python:
#    - https://www.python.org/about/gettingstarted/
#  - Introduction to Numpy: *The fundamental package for scientific computing with Python*
#    - https://numpy.org/devdocs/user/quickstart.html
#  - Introduction to Scikit-learn: python library for machine learning.
#    - https://scikit-learn.org/stable/getting_started.html

# %% [markdown]
# ## Introduction to python
#
#  - installation and development
#  - python basics

# %% [markdown]
# ### Installation
#
#  - in many operating systems python comes preinstalled
#  - Windows/Mac/Linux: everything can be easily installed and managed through Anaconda: https://www.anaconda.com/products/individual

# %% [markdown]
# ### Development
#  - various IDEs are available (Spyder, PyCharm, ...);
#  - python code does not need to be compiled! A simple text editor can be used to write code that is then executed by the `python` interpreter;
#  - python can be easily integrated with text and images inside notebooks (like this one): https://jupyter.org/
#  - many online interpreters/notebooks can be used to directly start programming: https://jupyter.org/try

# %% [markdown]
# ### Libraries
#  - a lot of libraries have been developed to extend Python capabilities
#  - they can be managed through `conda` or python's own package manager: `pip`
#
#  ```bash
#  pip install numpy
#  ```
#  - you can use `conda` or `pip` also to install jupyter notebooks!
#  ```
#  conda install -c conda-forge notebook
#
#  pip install notebook
#  ```

# %%
import numpy as np
np.random.random((2,3))
# Out:
# array([[0.49298146, 0.92872752, 0.79656318],
#        [0.92811953, 0.13687196, 0.45103103]])

# %% [markdown]
# ### Python basics: features
#  - highly readable code, simple syntax
#  - dynamically typed and garbage collected
#  - high flexibility. It supports procedural, object-oriented and functional programming.

# %% [markdown]
# ### Python basics: control flow
#  - `if` statements
#  - `for` and `while` loops
#  - other useful statements (`break`, `continue`, `pass`, ...) and functions (`range`, `enumerate`, `zip`)

# %%
a = 5
if a > 5:
    print("a>5")
elif a == 5:
    print("a=5")
else:
    print("a < 5")
# for a in range(10):
#     print(a)
# while a > 0:
#     print(a)
#     a -= 1
# Out:
# a=5
# 5
# 6
# 7

# %% [markdown]
# ### Python basics: data types
#  - dynamic typing

# %%
x = 3
print(type(x))
x = 'Hello'
type(x)
if isinstance(x, str):
    print("This is a string")
else:
    print(type(x))
# Out:
# <class 'int'>
# This is a string

# %%
z= False
type(z)
# Out:
# bool

# %% [markdown]
#  - default types (https://www.w3schools.com/python/python_datatypes.asp):
#
#  ![](https://github.com/paolotron/PythonCrashCourse/blob/main/types.png?raw=1)

# %% [markdown]
#  - new types can be easily defined using classes:(Defining Objects)

# %%
class Book:
    def __init__(self, title, author):
        self.title = title
        self.author = author
    def pretty_print(self):
        print('"' + self.title + '" by ' + self.author)

b = Book("The Lord of the Rings", "J.R.R. Tolkien")

b.pretty_print()
# Out:
# "The Lord of the Rings" by J.R.R. Tolkien

# %% [markdown]
# Because of dynamic typing sometimes objects definitions are a bit ambiguous.

# %% [markdown]
# ### Python basics: strings definition and manipulation
#
#  - strings support indexing and slicing
#  - strings are immutable
#  - concatenation and formatting is really easy
#  - useful predefined methods are available

# %%
# string definition and indexing
string = "Hello World"
hello = string[:6]
world = string[6:]
print(hello + world)
# Out:
# Hello World

# %%
x='This is Mohsen'
print(x[0])
print(x[-2])
a='Young'
b='theFirst'
print(a+' '+b)

"{} {}".format(b,a)
"Young theFirst".split(" ")
# Out:
# T
# e
# Young theFirst
# ['Young', 'theFirst']

# %%
# strings are immutable
try:
    string[5] = "_"
except TypeError:
    print("Strings are immutable!!")
# Out:
# Strings are immutable!!

# %%
# string concatenation
print(hello+world)
# string formatting
print("{}{}".format(hello, world))
print(f"{hello}{world}")
print("%s%s %d" % (hello, world, 1))
# Out:
# Hello World
# Hello World
# Hello World
# Hello World 1

# %%
# predefined methods
splitted = string.split(" ")
'_'.join(splitted)
# Out:
# 'Hello_World'

# %% [markdown]
# ### Python basics: lists definition and manipulation

# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %% [markdown]
# we use "while" when we dont know the number of repeatation of the loop

# %%
j = 0
while j<5:
      print(j)
      j+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
my_list=[1,2,3,4,5]
new_list=[]
for i in my_list:
    if i>3:
      new_list.append(i)

new_list.append('Hallo')

new_list
# Out:
# [4, 5, 'Hallo']

# %%
second_list=[3,5,7,9]
third_list=[i*2 for i in second_list if i>5]

third_list
# Out:
# [14, 18]

# %%
my_numbers = [4,6,7,5,3,2]
squares = []
even_numbers = []
for el in my_numbers:
    squares.append(el**2)
    if el%2 == 0:
        even_numbers.append(el)
print("Squares:", squares)
print("Even numbers:", even_numbers)
# Out:
# Squares: [16, 36, 49, 25, 9, 4]
# Even numbers: [4, 6, 2]

# %% [markdown]
# #### List comprehensions and filtering

# %%
my_numbers = [4,6,7,5,3,2]
squares = [el**2 for el in my_numbers]
even_numbers = [el for el in my_numbers if el%2==0]
print("Squares:", squares)
print("Even numbers:", even_numbers)
# Out:
# Squares: [16, 36, 49, 25, 9, 4]
# Even numbers: [4, 6, 2]

# %% [markdown]
# ### Python basics: functions

# %% [markdown]
# Defining a function by def.

# %%
def printVar(x1,x2):
  print(x1,' ',x2)

printVar(4,7)
printVar(8,8)
# Out:
# 4   7
# 8   8

# %% [markdown]
# Keyword "return" just print the sth is written inftont of it

# %%
import math

def euclidean_distance(x1, y1, x2, y2):
    return math.sqrt((x1 - x2)**2 + (y1 - y2)**2)

euclidean_distance(0,0,4,1)
# Out:
# 4.123105625617661

# %%
# using tuples:
def euclidean_distance_tuples(p1, p2):
    x1, y1 = p1
    x2, y2 = p2
    return math.sqrt((x1 - x2)**2 + (y1 - y2)**2)

p1 = (0,0)
p2 = (4,1)
print(euclidean_distance_tuples(p1,p2))
# Out:
# 4.123105625617661

# %% [markdown]
# ## Introduction to numpy
#
#  - definition of multidimensional arrays

# %%
import numpy as np
a = np.array([[1 ,2 ,3],[4,5,6]])
print("a = \n",a)
print("Shape:", a.shape)

#slicing the matrices
c = a[:,2:]
print(c)

b = np.linspace(0,2,20)
print("b = \n",[[b]])
print("Shape:",b.shape)
# Out:
# a =
#  [[1 2 3]
#  [4 5 6]]
# Shape: (2, 3)
# [[3]
#  [6]]
# b =
#  [[array([0.        , 0.10526316, 0.21052632, 0.31578947, 0.42105263,
#        0.52631579, 0.63157895, 0.73684211, 0.84210526, 0.94736842,
#        1.05263158, 1.15789474, 1.26315789, 1.36842105, 1.47368421,
#        1.57894737, 1.68421053, 1.78947368, 1.89473684, 2.        ])]]
# Shape: (20,)

# %% [markdown]
#  - useful tools for working with arrays (e.g: element-wise multiplication with lists vs numpy arrays)

# %%
# lists:
a = b = [[1,2],[3,4]]
c = [[0,0],[0,0]]
for i in range(len(a)):
    for j in range(len(b)):
        c[i][j] = a[i][j] * b[i][j]

# %%
# numpy arrays (when we want to do linear algebra with matrices always use numpy)
a = b = np.array([[1,2],[3,4]])
c = a * b

# %% [markdown]
#  - indexing and slicing

# %%
print(a)
#a[0]
#a[0,1]
#a[0][1]

#a[:,1]
#a[1,:]
# Out:
# [[1 2]
#  [3 4]]

# %% [markdown]
#  - operations:
#    - element-wise operations
#    - broadcasting (operations between different arrays of different sizes)

# %%
print(a+b)
print(a-b)
print(a*b)
# Out:
# [[2 4]
#  [6 8]]
# [[0 0]
#  [0 0]]
# [[ 1  4]
#  [ 9 16]]

# %%
print(a+1)
print(a*2)
# Out:
# [[2 3]
#  [4 5]]
# [[2 4]
#  [6 8]]

# %%
import matplotlib.pyplot as plt  #the library for dealing with plot and images
import random

cat = plt.imread('2.jpg')
print("Type", type(cat), "Shape", cat.shape)
plt.imshow(cat)
# Out:
# Type <class 'numpy.ndarray'> Shape (2976, 3968, 3)

# %%
print(type(cat))
h, w = cat.shape[0], cat.shape[1]
side = int(0.5*(min(h,w)))
i = random.randint(0,h-side)
j = random.randint(0,w-side)
cat_crop = cat[i:i+side,j:j+side]
plt.imshow(cat_crop)
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# **Exercise 2**: gray scale image

# %% [markdown]
# for some applications only we need is balck and white format not colors , like handwriting detection.

# %%
import numpy as np
print(cat.shape)
print(np.sum(cat, axis=1).shape) #added by mohsen
gray_cat = cat.sum(2)  #Just sum up all elements on the third dimension into one
print(gray_cat.shape)
plt.imshow(gray_cat, cmap='gray')
# Out:
# (2976, 3968, 3)
# (2976, 3)
# (2976, 3968)

# %% [markdown]
# ## Introduction to scikit-learn
# Machine learning library built on top of numpy. Features:
#
#  - includes definitions of machine learning algorithms for classification, clustering, regression... e.g.: SVM, k-means, random forest, linear regression...
#  - it also contains classes and functions useful to simplify research: data preprocessing, model selection, ...

# %% [markdown]
# ### Naive Bayes
# Problem:
#  - we have a set of points with 2 dimensions. Each point is assigned a label between 0 and 1;
#  - we want to build a Gaussian Naive Bayes classifier able to predict the label of new points.

# %%
from sklearn.datasets import make_blobs
X, y = make_blobs(100, 2, random_state=2, centers=2, cluster_std=1.5)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='RdBu');

# %% [markdown]
# We use the Bayes' theorem:
# $$
# P (L|\textit{features}) = \cfrac{P(\textit{features}|L)P(L)}{P(\textit{features})}
# $$
#
# For each label $L_i$ we want to compute $P(\textit{features}|L_i)$.
#
# If we use a *Gaussian* Naive Bayes approach we make the assumption that *data from each label is drawn from a simple Gaussian distribution*. So we need to estimate for each label the mean and the variance for the values of the various features. We also assume that there is no covariance between the features. / masks are boolean array

# %%
x_0 = X[y==0]
x_1 = X[y==1]

# %%
mask_l0 = y==0
mask_l1 = y==1
mean_l0 = X[mask_l0].mean(0)
mean_l1 = X[mask_l1].mean(0)
var_l0 = X[mask_l0].var(0)
var_l1 = X[mask_l1].var(0)
print("Mean l0: {}. l1: {}".format(mean_l0, mean_l1))
print("Var l0: {}. l1: {}".format(var_l0, var_l1))
# Out:
# Mean l0: [-1.64939095 -9.36891451]. l1: [ 1.29327924 -1.24101221]
# Var l0: [2.06097003 2.4771687 ]. l1: [3.33164805 2.22401382]

# %% [markdown]
# Now when we receive a new point we can compute the probability for the two classes and make a prediction.

# %%
from scipy.stats import norm

dist_l0_f0, dist_l0_f1 = norm(mean_l0[0], math.sqrt(var_l0[0])), norm(mean_l0[1], math.sqrt(var_l0[1]))
dist_l1_f0, dist_l1_f1 = norm(mean_l1[0], math.sqrt(var_l1[0])), norm(mean_l1[1], math.sqrt(var_l1[1]))

def prob_l0(point):
    return dist_l0_f0.pdf(point[0])*dist_l0_f1.pdf(point[1])
def prob_l1(point):
    return dist_l1_f0.pdf(point[0])*dist_l1_f1.pdf(point[1])
def predict_p(point):
    if prob_l0(point) > prob_l1(point):
        return 0
    else:
        return 1
def predict_set(points):
    points = [predict_p(point) for point in points]
    return np.array(points)

# %%
Xnew = [-6, -14] + [14, 18] * np.random.rand(2000, 2)
ynew = predict_set(Xnew)

plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='RdBu')
lim = plt.axis()
plt.scatter(Xnew[:, 0], Xnew[:, 1], c=ynew, s=20, cmap='RdBu', alpha=0.1)
plt.axis(lim);

# %% [markdown]
# GaussianNB is already implemented in `scikit-learn`!

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X, y);

# %% [markdown]
# It internally computes the same statistics:

# %%
print("GNB mean:",model.theta_)
print("Mean l0: {}. l1: {}".format(mean_l0, mean_l1))
# Out:
# GNB mean: [[-1.64939095 -9.36891451]
#  [ 1.29327924 -1.24101221]]
# Mean l0: [-1.64939095 -9.36891451]. l1: [ 1.29327924 -1.24101221]

# %%
ynew = model.predict(Xnew)
plt.scatter(X[:, 0], X[:, 1], c=y, s=50, cmap='RdBu')
lim = plt.axis()
plt.scatter(Xnew[:, 0], Xnew[:, 1], c=ynew, s=20, cmap='RdBu', alpha=0.1)
plt.axis(lim);

# %% [markdown]
# ### Linear regression
# **Problem**:
#
#  - we have a dataset which associates observations of a value $x$ with a corresponding target value $y$;
#  - given a new $x$ we want to be able to predict $y$.

# %% [markdown]
# **Exercise 1**: straight line
#
# We use the linear regression to model a function like:
# $$
# y = a_0 + a_1 x
# $$

# %%
n_points=100
x = 10 * np.random.rand(n_points)
y = 2 * x - 5 + np.random.randn(100)
plt.scatter(x, y);

# %% [markdown]
# We can use `scikit-learn`'s `LinearRegression` estimator to fit our data and construct the best-fit line

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept=True)

# the reshape is necessary: sklearn needs to know if this array contains many points
# with a single value or a single point with many values
model.fit(x.reshape(-1, 1), y);

# %% [markdown]
# We can plot the estimated line together with the training data:

# %%
xfit = np.linspace(0, 10, 1000)
yfit = model.predict(xfit.reshape(-1,1))

plt.scatter(x, y)
plt.plot(xfit, yfit, color='red');

# %% [markdown]
# We can also obtain the parameters of our line:

# %%
print("Model slope: {:.4f}".format(model.coef_[0]))
print("Model intercept: {:.4f}".format(model.intercept_))
# Out:
# Model slope: 1.9811
# Model intercept: -5.0184

# %% [markdown]
# **Exercise 2**: non linear relationships
#
# A linear regression could be used also to fit a function like:
# $$
# y=a_0 + a_1 x + a_2 x^2 + a_3 x^3 + ...
# $$
#
# In the name *Linear Regression* the term *linear* refers to the fact that the coefficients $a_n$ never multiply or divide each other.

# %% [markdown]
# In order to apply our Linear Regression model in this situation we have to transform our data. In practice we consider a multidimensional linear model:
# $$
# y = a_0 + a_1 x_1 + a_2 x_2 + a_3 x_3 + ...
# $$
# And we build the $x_1$, $x_2$, $x_3$ from our single dimensional input $x$:
#  - $x_1 = x$;
#  - $x_2 = x^2$;
#  - ...
#
# We can do this really easily using a *transformer* integrated in `scikit-learn`.

# %% [markdown]
# Example of application of the `PolynomialFeatures` transformer:

# %%
from sklearn.preprocessing import PolynomialFeatures
x = np.array([2, 3, 4])
poly = PolynomialFeatures(4, include_bias=False)
poly.fit_transform(x.reshape(-1,1))
# Out:
# array([[  2.,   4.,   8.,  16.],
#        [  3.,   9.,  27.,  81.],
#        [  4.,  16.,  64., 256.]])

# %% [markdown]
# In our problem we consider data generated using a $sin$ function with added noise.
# This is an useful example as there is a global and general regularity (that we wish to learn) but local observations are corrupted by noise.

# %%
x = np.random.rand(n_points)
y = np.sin(2 * np.pi * x) + 0.1 * np.random.randn(n_points)
plt.scatter(x=x, y=y)
plt.show()

# %% [markdown]
# To solve the problem we want to use both the `PolynomialFeatures` transformer and the `LinearRegression` model. We can use the `make_pipeline` function provided by `scikit-learn` so that we do not need to perform the data transformation and model fitting in two separated steps

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import PolynomialFeatures

poly_model = make_pipeline(PolynomialFeatures(7),
                           LinearRegression())
poly_model.fit(x.reshape(-1,1), y);

# %%
yfit = poly_model.predict(xfit.reshape(-1,1))

plt.scatter(x, y)
lim = plt.axis()
plt.plot(xfit, yfit, color='red');
plt.axis(lim);

# %% [markdown]
# ### Classification on handwritten Digits and Principal Component Analysis

# %%
import sklearn
from sklearn.datasets import load_digits
X, y = load_digits(return_X_y=True)
print(X.shape)
# Out:
# (1797, 64)

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1 import ImageGrid

fig = plt.figure(figsize=(10., 4.))
grid = ImageGrid(fig, 111, nrows_ncols=(2, 5), axes_pad=0.1)
for idx, ax in enumerate(grid):
    ax.imshow(X[idx].reshape(8,8), cmap='gray')

plt.show()

# %% [markdown]
# Define **training set** and **test set**.

# %%
X_train, y_train = X[:-200], y[:-200]
X_test, y_test = X[-200:], y[-200:]

# %% [markdown]
# **Normalize data**: many machine learning algorithms work better on standardized data (0 mean and unit variance)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# **Instantiate model** and **train it**

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train);

# %% [markdown]
# **Test model** and **compute accuracy**

# %%
random_test_sample = X_test[np.random.choice(len(X_test))].reshape(1,-1)

plt.imshow(scaler.inverse_transform(random_test_sample).reshape(8,8), cmap='gray')

# %%
print("Predicted class:", model.predict(random_test_sample))
# Out:
# Predicted class: [9]

# %%
print("Accuracy:", model.score(X_test, y_test))
# Out:
# Accuracy: 0.74

# %% [markdown]
# #### Dimensionality reduction

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=20).fit(X_train)
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)

# %%
# check size
print(X_train_pca.shape)
# check retained information ratio
print(pca.explained_variance_ratio_.sum())
# Out:
# (1597, 20)
# 0.7963172481763254

# %% [markdown]
# Train model and compute accuracy

# %%
model_pca = GaussianNB()
model_pca.fit(X_train_pca, y_train);
print("Accuracy:", model_pca.score(X_test_pca, y_test))

# %% [markdown]
# References:
#  - https://github.com/jakevdp/PythonDataScienceHandbook
#  - https://github.com/lucmos/DLAI-s2-2020-tutorials/blob/master/03/03_Linear_models_and_Pytorch_Datasets.ipynb
